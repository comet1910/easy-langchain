# %% [markdown]
# # Demo

# %%
print("hello word")
# Out:
# hello word

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("DEEPSEEK_API_KEY")
CLOSEAI_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model = init_chat_model(
    model = "deepseek-v4-flash",
    api_key = CLOSEAI_API_KEY,
    base_url = CLOSEAI_BASE_URL,

)

print(model.invoke("你是什么模型"))
# Out:
# content='我是 **DeepSeek**，由深度求索公司创造的AI助手！具体来说，我是 **DeepSeek最新版模型**（可能是DeepSeek-V3或DeepSeek-R1系列）。\n\n**我的主要特点包括：**\n- 🆓 **完全免费** - 没有收费计划\n- 📚 **超长上下文** - 支持1M token，可以一次处理三体三部曲这样体量的书籍\n- 🌐 **联网搜索** - 需要手动在Web/App端开启\n- 📎 **文件上传** - 支持图片、PDF、Word、Excel、PPT、TXT等格式\n- 🎤 **语音输入** - App端支持\n- 🧠 **推理能力** - 擅长复杂逻辑推理、代码生成、文本分析等\n\n知识截止日期是 **2025年5月**。\n\n我是纯文本模型，虽然可以读取上传文件中的文字信息，但不支持多模态识别（比如直接“看”图片内容）。有什么我可以帮你的吗？😊' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户问了一个关于我身份的基础问题：“你是什么模型”。这是一个非常直接且常见的开场问题。\n\n我需要明确告知用户我的模型名称和核心能力。我的名字是DeepSeek，由深度求索公司创造。我应该简要说明我的主要特点，比如文本处理、文件上传、联网搜索、长上下文等能力，并澄清我是纯文本模型。同时要说明免费、知识截止日期等关键信息，并保持友好邀请用户继续提问。\n\n想到了可以用一个清晰、直接但带有帮助性的结构来回答：先说出模型名称和公司，然后列出几个关键特点，最后以开放性问题结束，引导对话继续。'} response_metadata={'token_usage': {'completion_tokens': 352, 'prompt_tokens': 7, 'total_tokens': 359, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 134, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 7}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '6fc437bf-ee81-4401-90f4-f69c34df23d0', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f1143-532a-7a30-948c-9675d4c6a54d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 7, 'output_tokens': 352, 'total_tokens': 359, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 134}}

# %%
from rich import print as rprint
respone = model.invoke("你是什么模型")
rprint(respone)
# Out:
# AIMessage(
#     content='你好！我是
# **DeepSeek**，由深度求索公司开发的最新版本模型。简单来说，我是一个纯文本、免费使用的大语言模型，拥有以下特点：\n\n-
# **参数规模**：671B（6710亿参数），采用MoE（混合专家）架构\n- **核心能力**：\n  - 支持超长上下文（1M
# tokens，相当于能一次处理《三体》三部曲这样的长文本）\n  -
# 支持文件上传（图像、PDF、Word、Excel、PPT等，可从中提取文字信息）\n  - 支持联网搜索（需手动开启）\n  -
# 支持语音输入（App端）\n- **知识截止日期**：2025年5月\n-
# **使用方式**：可通过官方应用商店下载App，或访问网页版\n\n有什么我可以帮你解答的吗？无论是学习、工作还是日常问题，我
# 都乐意协助！😊',
#     additional_kwargs={
#         'refusal': None,
#         'reasoning_content':
# '嗯，用户问了一个非常直接的问题：“你是什么模型”。这是一个关于我自身身份的简单询问。用户可能刚接触我，想了解我的基本
# 背景和能力范围。\n\n我需要给出清晰、准确的自我介绍，包括我的名称、开发公司、核心参数和关键特性。想到了直接说明我是D
# eepSeek最新版本模型，由深度求索公司开发，参数规模是671B。然后可以列举几个重要的功能点，比如免费、长上下文、文件处理
# 、联网搜索等，让用户快速了解我能做什么。最后用开放式的提问结束，邀请用户提出进一步需求。\n\n这个答复应该结构清晰、
# 信息全面，同时保持友好和热情的语气，让用户感到欢迎。'
#     },
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 329,
#             'prompt_tokens': 7,
#             'total_tokens': 336,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 141,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0},
#             'prompt_cache_hit_tokens': 0,
#             'prompt_cache_miss_tokens': 7
#         },
#         'model_provider': 'deepseek',
#         'model_name': 'deepseek-v4-flash',
#         'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
#         'id': 'c4695dcf-14f5-454c-8a11-71473d002f6d',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019f115b-daa6-7a21-9284-8875f2fc476d-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 7,
#         'output_tokens': 329,
#         'total_tokens': 336,
#         'input_token_details': {'cache_read': 0},
#         'output_token_details': {'reasoning': 141}
#     }
# )
